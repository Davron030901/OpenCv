# %% [markdown]
# #Feature Detetion

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
# !wget https://raw.githubusercontent.com/Davron030901/OpenCv/main/OpenCV_Python_Developers/03_Face_and_Feature%20Detection/template.jpg
# !wget https://raw.githubusercontent.com/Davron030901/OpenCv/main/OpenCV_Python_Developers/03_Face_and_Feature%20Detection/players.jpg
# !wget https://raw.githubusercontent.com/Davron030901/OpenCv/main/OpenCV_Python_Developers/03_Face_and_Feature%20Detection/haarcascade_frontalface_default.xml
# Out:
# --2025-02-05 12:21:48--  https://raw.githubusercontent.com/Davron030901/OpenCv/main/OpenCV_Python_Developers/03_Face_and_Feature%20Detection/template.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3076 (3.0K) [image/jpeg]
# Saving to: ‘template.jpg’
#
# template.jpg        100%[===================>]   3.00K  --.-KB/s    in 0s
#
# 2025-02-05 12:21:48 (12.4 MB/s) - ‘template.jpg’ saved [3076/3076]
#
# --2025-02-05 12:21:48--  https://raw.githubusercontent.com/Davron030901/OpenCv/main/OpenCV_Python_Developers/03_Face_and_Feature%20Detection/players.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.110.133, ...
# ...

# %%
template = cv2.imread('template.jpg', 0)
print("Template")
cv2_imshow(template)
# Out:
# Template
# <PIL.Image.Image image mode=L size=56x48>

# %%
frame = cv2.imread('players.jpg', 0)
print("Frame")
cv2_imshow(frame)
# Out:
# Frame
# <PIL.Image.Image image mode=L size=544x363>

# %%
result = cv2.matchTemplate(frame, template, cv2.TM_CCOEFF_NORMED)
min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(result)
print(max_val,max_loc)
cv2.circle(result,max_loc, 15,255,2)
print("Result")
cv2_imshow(result)
# Out:
# 0.4659745395183563 (132, 243)
# Result
# <PIL.Image.Image image mode=L size=489x316>

# %% [markdown]
# #Face Detection

# %%
# !wget https://raw.githubusercontent.com/Davron030901/OpenCv/main/OpenCV_Python_Developers/03_Face_and_Feature%20Detection/faces.jpeg
# Out:
# --2025-02-05 12:21:49--  https://raw.githubusercontent.com/Davron030901/OpenCv/main/OpenCV_Python_Developers/03_Face_and_Feature%20Detection/faces.jpeg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 284245 (278K) [image/jpeg]
# Saving to: ‘faces.jpeg’
#
# faces.jpeg          100%[===================>] 277.58K  --.-KB/s    in 0.06s
#
# 2025-02-05 12:21:50 (4.86 MB/s) - ‘faces.jpeg’ saved [284245/284245]

# %%
img = cv2.imread('faces.jpeg', 1)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
path="haarcascade_frontalface_default.xml"
face_cascade = cv2.CascadeClassifier(path)

# %%
faces=face_cascade.detectMultiScale(gray,scaleFactor=1.10,minNeighbors=5,minSize=(40,40))

# %%
print(len(faces))
# Out:
# 24

# %%
for x,y,w,h in faces:
  cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
print("Faces Detection")
cv2_imshow(img)
# Out:
# Faces Detection
# <PIL.Image.Image image mode=RGB size=750x750>

# %% [markdown]
# #Eye detection

# %%
# !wget https://raw.githubusercontent.com/Davron030901/OpenCv/main/OpenCV_Python_Developers/03_Face_and_Feature%20Detection/haarcascade_eye.xml
# Out:
# --2025-02-05 12:27:05--  https://raw.githubusercontent.com/Davron030901/OpenCv/main/OpenCV_Python_Developers/03_Face_and_Feature%20Detection/haarcascade_eye.xml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 341406 (333K) [text/plain]
# Saving to: ‘haarcascade_eye.xml’
#
# haarcascade_eye.xml 100%[===================>] 333.40K  --.-KB/s    in 0.06s
#
# 2025-02-05 12:27:06 (5.46 MB/s) - ‘haarcascade_eye.xml’ saved [341406/341406]

# %%
img=cv2.imread('faces.jpeg',1)
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
path="haarcascade_eye.xml"
eye_cascade=cv2.CascadeClassifier(path)

# %%
eyes=eye_cascade.detectMultiScale(gray,scaleFactor=1.02,minNeighbors=20,minSize=(10,10))
print(len(eyes))
# Out:
# 43

# %%
for x,y,w,h in eyes:
  xc=(x+x+w)/2
  yc=(y+y+h)/2
  radius=w/2
  cv2.circle(img,(int(xc),int(yc)),int(radius),(255,0,0),2)
print("Eyes Detection")
cv2_imshow(img)
# Out:
# Eyes Detection
# <PIL.Image.Image image mode=RGB size=750x750>
