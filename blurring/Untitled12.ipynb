# %% [markdown]
# <a href="https://colab.research.google.com/github/Davron030901/blurring/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow

import cv2


img = cv2.imread('/content/cow-salt-peper.png')

k_size = 7
img_blur = cv2.blur(img, (k_size, k_size))
img_gaussian_blur = cv2.GaussianBlur(img, (k_size, k_size), 5)
img_median_blur = cv2.medianBlur(img, k_size)

cv2_imshow( img)
cv2_imshow( img_blur)
cv2_imshow(img_gaussian_blur)
cv2_imshow( img_median_blur)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x664>
# <PIL.Image.Image image mode=RGB size=1000x664>
# <PIL.Image.Image image mode=RGB size=1000x664>
# <PIL.Image.Image image mode=RGB size=1000x664>
# -1
